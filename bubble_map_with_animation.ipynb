# %%
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter_geo(df, locations="iso_alpha", color="continent",
                     hover_name="country", size="pop",
                     animation_frame="year",
                     projection="natural earth")
fig.show()

# %%
import pandas as pd
df_historic = pd.read_csv('./data/women_in_parliament-historical_database-1945_to_2018_cleaned.csv')
df_historic = df_historic.query("chamber_type != 'upper' ")

df_2021_regions = pd.read_csv('./data/women_percent_as_of2021_with_regions.csv')
df_iso = df_2021_regions[['country','iso3']]

df_historic_iso = df_historic.merge(df_iso, on='country').reset_index()

df_historic_iso = df_historic_iso.dropna(subset=['women_perc'])

# %%
df_historic_iso[df_historic_iso['country']=='Botswana']['iso3']
# Out:
# 224    BWA
# 225    BWA
# 226    BWA
# 227    BWA
# 228    BWA
# 229    BWA
# 230    BWA
# 231    BWA
# 232    BWA
# 233    BWA
# 234    BWA
# Name: iso3, dtype: object

# %%
fig = px.scatter_geo(df_historic_iso, locations="iso3", color="country",
                     hover_name="country", size="women_perc",
                     animation_frame="year",
                     projection="natural earth")
fig.show()

# %%
df_historic_iso.head()
# Out:
#    index      country region election_renewal  year month chamber_type  \
# 0      0  Afghanistan   ASIA              Yes  1965  July        lower
# 1      1  Afghanistan   ASIA              Yes  1969   NaN        lower
# 2      2  Afghanistan   ASIA              Yes  1988   NaN        lower
# 3      3  Afghanistan   ASIA              Yes  2005   NaN        lower
# 4      4  Afghanistan   ASIA              Yes  2010   NaN        lower
#
#   chamber_total_seats  women_total  women_perc  \
# 0                 210          4.0        0.02
# 1                 216          0.0        0.00
# 2                 235          7.0        0.03
# 3                 249         68.0        0.27
# 4                 249         69.0        0.28
#
#                                                notes  decade iso3
# 0  First legislature of Afghanistan after the abo...    1960  AFG
# 1  Parliament was dissolved following a military ...    1960  AFG
# ...

# %%
import plotly.express as px
df = px.data.medals_long()

fig = px.scatter(df_historic_iso, x="country", y="women_perc", color="year"
                ,labels=dict(women_perc='Women (%)', year='Year', country='Country')
                ,title='Women Representation in Parliament Through the Years - Country Level',)
fig.update_traces(marker_size=10)

fig.update_traces(marker=dict(size=8,
                              line=dict(width=1,
                                        color='blue')),
                  selector=dict(mode='markers'))

fig.update_layout(
        font_family="Courier New",
        font_color="grey",
        title_font_family="Courier New",
        title_font_color="#1f77b4",
        legend_title_font_color="grey",
        autosize=False,
        width=1100,
        height=800
        )



fig.show()
